# %%
import numpy as np
from skimage import io 
photo = io.imread('482434.jpg')

# %%
photo
# Out:
# array([[[ 10,  36,  73],
#         [ 14,  38,  76],
#         [ 12,  36,  74],
#         ...,
#         [ 27,  69,  93],
#         [ 20,  62,  84],
#         [ 17,  59,  81]],
#
#        [[  7,  33,  70],
#         [ 11,  35,  73],
#         [  9,  33,  71],
#         ...,
#         [ 35,  77, 102],
#         [ 31,  73,  97],
#         [ 24,  66,  88]],
#
#        [[  7,  33,  70],
#         [  8,  34,  69],
#         [  7,  31,  67],
#         ...,
#         [ 40,  82, 107],
#         [ 38,  80, 105],
#         [ 27,  69,  93]],
#
#        ...,
#
#        [[ 17,  17,  17],
#         [ 18,  18,  18],
#         [ 19,  19,  19],
#         ...,
#         [ 95,  95,  95],
#         [ 95,  95,  95],
#         [ 95,  95,  95]],
#
#        [[ 16,  16,  16],
#         [ 17,  17,  17],
#         [ 18,  18,  20],
#         ...,
#         [ 94,  94,  94],
#         [ 93,  93,  93],
#         [ 92,  92,  92]],
#
#        [[ 15,  15,  15],
#         [ 17,  17,  17],
#         [ 18,  18,  20],
#         ...,
#         [109, 109, 109],
#         [109, 109, 109],
#         [106, 106, 106]]], dtype=uint8)

# %%
photo.shape
# Out:
# (2160, 3840, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:, ::-1])

# %%
plt.imshow(photo[250:1000])

# %%
plt.imshow(photo[::2, ::2])

# %%
plt.imshow(photo[:,:,0].T)

# %%
plt.imshow(photo[:,:,2].T)

# %%
##photo_sin = np.sin(photo)
##photo_sin[:10]

# %%
print(np.sum(photo))
# Out:
# 1732438536

# %%
print(np.prod(photo))
# Out:
# 0

# %%
print(np.mean(photo))
# Out:
# 69.6228192515432

# %%
print(np.std(photo))
# Out:
# 64.18514316121772

# %%
print(np.var(photo))
# Out:
# 4119.732602626014

# %%
print(np.min(photo))
# Out:
# 0

# %%
print(np.max(photo))
# Out:
# 255

# %%
print(np.argmin(photo))
# Out:
# 318

# %%
print(np.argmax(photo))
# Out:
# 1661
